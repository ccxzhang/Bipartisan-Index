# %%
import os
import pandas as pd
import glob
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import random

# %%
class Paraguay:
    '''
    The class uses packages shown as below:
        BeautifulSoup4  4.9.3;
        glob2  0.7;
        selenium  3.141.0;
        pandas  1.2.0;    
    '''
    
    
    def __init__(self, id):
        self.id= id

    
    def setUp(self):
        
        ## Set download options
        opts= Options()
        opts.add_experimental_option("prefs",{"download.prompt_for_download": False,
                                              "download.directory_upgrade": True,
                                              "safebrowsing.enabled": True})
        ## Initiate the driver
        self.driver= webdriver.Chrome("/Applications/chromedriver", options= opts)

        ## Get current working directory
        path= os.getcwd()
        download_dir= path + "/data"
        
        ## Set Chrome to trust downloads
        self.driver.command_executor._commands["send_command"]= ("POST", '/session/$sessionId/chromium/send_command')
        params= {'cmd': 'Page.setDownloadBehavior', 'params': {'behavior': 'allow', 'downloadPath': download_dir}}
        command_result= self.driver.execute("send_command", params)


    def click(self):

        ## Access the URL
        url= "https://portaldjbr.contraloria.gov.py/portal-djbr/"
        self.driver.get(url)

        ## Use xpath to fill the id form
        element= self.driver.find_element_by_xpath('//*[@id="app"]/div[2]/div/div/div/div[2]/div[2]/input')
        element.send_keys(self.id)
        
        ## Find and click the search button
        search_button= self.driver.find_element_by_xpath('//*[@id="app"]/div[2]/div/div/div/div[2]/div[3]/button')
        search_button.click()
    
    
    def downloadFiles(self):

        docs_info= [i.text for i in self.driver.find_elements_by_xpath("//td")]

        ## Produce a list of clear filenames
        names=[]
        year=[]
        filenames=[]
        for key, value in enumerate(docs_info):
            if key %4==0:
                names.append(value)
            
            if key %4==2:
                year.append(value)
                filenames.append(str(self.id) + "_" + value)
                
                
        download_buttons= self.driver.find_elements_by_class_name("p-button-success")
        
        ## Check whether the database exists one's disclosure
        if len(download_buttons)==0: 
            print("There is no "+ str(self.id)+ "'s records.")
        
        else: 
            for index, button in enumerate(download_buttons):

                ## Randomly sleep
                time.sleep(random.uniform(1,3))

                ## Print the (name, year) for check
                print("Job "+ str(index+1)+ ": The file is from "+ names[index]+ " (" + str(self.id) + ")" + " in "+ year[index]+ ".")

                ## Click the download button
                button.click()

                ## Wait for sometime to finish the downloading process
                time.sleep(20)

                ## Get the latest files within the directory
                files= glob.glob("data/*")
                latest= max(files, key=os.path.getctime)   

                filename= "data/" + filenames[index]+ ".pdf"
                alternative= "data/" + filenames[index]+ "_1" + ".pdf"
                second_alternative= "data/" + filenames[index]+ "_2" + ".pdf"
                third_alternative= "data/" + filenames[index]+ "_3" + ".pdf"


                ## If the filename doesn't exist, then rename the latest file as the pre-created name
                if (os.path.exists(filename)== False):

                    ## Rename the files by "id_year"
                    os.rename(os.path.join(latest), os.path.join(filename))

                elif (os.path.exists(alternative)== False): 

                    ## if one year has two documents, implement the alternative name
                    os.rename(os.path.join(latest), os.path.join(alternative))

                elif (os.path.exists(second_alternative)== False): 
                    os.rename(os.path.join(latest), os.path.join(second_alternative))
                
                else: 
                    os.rename(os.path.join(latest), os.path.join(third_alternative))
                    


        self.driver.quit()
        
        return download_status

# %% [markdown]
# ## VP

# %%
## load the vp data
## id== 832988 or 652236 also exists in legislators
vp= pd.read_csv("~/Desktop/Paraguay/vp-id-list.csv")
vp_lists= vp["id"].to_list()
vp_lists
# Out:
# [389672, 652236, 352252, 832988]

# %% [markdown]
# ## Cabinet

# %%
cabinet= pd.read_csv("~/Desktop/Paraguay/cabinet-id-list.csv")
cabinet_lists= cabinet["id"].to_list()
cabinet_lists
# Out:
# [404976,
#  453913,
#  238610,
#  1336946,
#  1047386,
#  677755,
#  1123122,
#  409636,
#  1388499,
#  85848,
#  931976,
#  1699606,
#  219847,
#  232663,
#  913111,
#  992145,
#  637256,
#  1527620,
#  446027,
#  232627,
#  1164164,
#  316204,
#  3569632,
#  694926,
#  838771,
#  1123415,
#  618781,
#  725119,
#  402938,
#  2102663,
#  435101,
#  3548659,
#  648993,
#  380218,
#  2849697,
#  619890,
#  1467955,
#  1786719,
#  346742,
#  608726,
#  3727699,
#  1890292,
#  923198,
#  920868,
#  487021,
#  686959,
#  876798,
#  835848,
#  902726,
#  1384728,
#  3400701,
#  3382061,
#  766742,
#  3031787,
#  1056514,
#  886807,
#  3492337,
#  1431114,
#  391746,
#  2209022,
#  770933,
#  640913,
#  2352438,
#  1217833,
#  1194695,
#  1099091,
#  1260233,
#  2513962,
#  2864308,
#  905999,
#  610668,
#  916313,
#  1742102,
#  987143,
#  852751,
#  745882,
#  1137105,
#  346942,
#  2974481,
#  1362380,
#  603957]

# %%
## Check whether there are overlappings between vp and cabinet 
for id in vp_lists: 
    if id in cabinet_lists:
        print("Yes")
        cabinet_lists.remove(id)
    else: 
        pass

# %%
for id in cabinet_lists:
    cab= Paraguay(id= id)
    cab.setUp()
    time.sleep(3)
    cab.click()
    time.sleep(3)
    cab.downloadFiles()
# Out:
# There is no 404976's records.
# Job 1: The file is from MARTIN LUIS,BURT,ARTAZA (453913) in 2001.
# Job 2: The file is from MARTIN LUIS,BURT,ARTAZA (453913) in 2012.
# Job 3: The file is from MARTIN LUIS,BURT,ARTAZA (453913) in 2013.
# There is no 238610's records.
# Job 1: The file is from NURIA RENINSEB ISNARDI MARTINEZ (1336946) in 2018.
# Job 2: The file is from NURIA RENINSEB ISNARDI MARTINEZ (1336946) in 2019.
# Job 3: The file is from NURIA RENINSEB ISNARDI DE PEREIRA (1336946) in 2002.
# Job 4: The file is from NURIA RENINSEB ISNARDI MARTINEZ (1336946) in 1999.
# Job 5: The file is from NURIA RENINSEB ISNARDI MARTINEZ (1336946) in 2012.
# Job 1: The file is from HUMBERTO RUBEN PERALTA BEAUFORT (1047386) in 2018.
# Job 2: The file is from HUMBERTORUBEN PERALTABEAUFORT (1047386) in 2001.
# Job 3: The file is from HUMBERTORUBEN PERALTABEAUFORT (1047386) in 2006.
# Job 4: The file is from HUMBERTORUBEN PERALTABEAUFORT (1047386) in 2013.
# Job 5: The file is from HUMBERTORUBEN PERALTABEAUFORT (1047386) in 2014.
# Job 6: The file is from HUMBERTO RUBEN PERALTA BEAUFORT (1047386) in 2001.
# Job 7: The file is from HUMBERTO RUBEN PERALTA BEAUFORT (1047386) in 2006.
# Job 8: The file is from HUMBERTO RUBEN PERALTA BEAUFORT (1047386) in 2013.
# Job 9: The file is from HUMBERTO RUBEN PERALTA BEAUFORT (1047386) in 2014.
# Job 1: The file is from GRACIELA LILIANA MARIA BARTOLOZZI DE ORTUZAR (677755) in 2018.
# Job 1: The file is from JOSE MARIA ORUE ROLANDI (1123122) in 2016.
# Job 2: The file is from JOSE MARIA ORUE ROLANDI (1123122) in 2012.
# Job 1: The file is from MARCELO LUIS BEDOYA (409636) in 2013.
# Job 2: The file is from MARCELO LUIS BEDOYA MURTO (409636) in 2012.
# Job 1: The file is from LIZ ROSANNA CRAMER CAMPOS (1388499) in 2018.
# Job 2: The file is from LIZROSANNA CRAMERCAMPOS 2006 (1388499) in 1.
# Job 3: The file is from LIZROSANNA CRAMERCAMPOS 2006 (1388499) in 2.
# Job 4: The file is from LIZROSANNA CRAMERCAMPOS (1388499) in 2009.
# Job 5: The file is from LIZROSANNA CRAMERCAMPOS (1388499) in 2013.
# Job 6: The file is from LIZ ROSANNA CRAMER CAMPOS (1388499) in 2006.
# Job 7: The file is from LIZ ROSANNA CRAMER CAMPOS (1388499) in 2006.
# Job 8: The file is from LIZ ROSANNA CRAMER CAMPOS (1388499) in 2009.
# Job 9: The file is from LIZ ROSANNA CRAMER CAMPOS (1388499) in 2013.
# There is no 85848's records.
# There is no 931976's records.
# Job 1: The file is from HECTOR RAMON CARDENAS MOLINAS (1699606) in 2018.
# Job 2: The file is from HECTOR RAMON CARDENAS MOLINAS (1699606) in 2008.
# Job 3: The file is from HECTOR RAMON CARDENAS MOLINAS (1699606) in 2013.
# Job 4: The file is from HECTOR RAMON CARDENAS MOLINAS (1699606) in 2014.
# Job 1: The file is from RICHARD WILLIAM KENT FERREIRA (219847) in 2013.
# Job 2: The file is from RICHARD WILLIAM KENT FERREIRA (219847) in 2013.
# Job 1: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 2018.
# Job 2: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 1998.
# Job 3: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 2003.
# Job 4: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 2006.
# Job 5: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 2008.
# Job 6: The file is from JUAN CARLOS,RAMIREZ,MONTALBETTI (232663) in 2013.
# Job 7: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 2013.
# Job 8: The file is from JUAN CARLOS RAMIREZ MONTALBETTI (232663) in 2013.
# Job 1: The file is from JOSE RAMON MOLINAS VEGA (913111) in 2018.
# Job 2: The file is from JOSE RAMON MOLINAS VEGA (913111) in 2014.
# Job 1: The file is from FABRIZIO CALIGARIS RAMOS (992145) in 2016.
# Job 2: The file is from FABRIZIO CALIGARIS RAMOS (992145) in 2018.
# Job 3: The file is from FABRIZIO CALIGARIS RAMOS (992145) in 2014.
# Job 1: The file is from FERNANDO DANIEL OJEDA CACERES (637256) in 2014.
# Job 2: The file is from FERNANDO DANIEL OJEDA CACERES (637256) in 2019.
# Job 1: The file is from HECTOR DAVID OCAMPOS NEGREIROS (1527620) in 2014.
# Job 2: The file is from HECTOR DAVID OCAMPOS NEGREIROS (1527620) in 2018.
# Job 3: The file is from HECTOR DAVID OCAMPOS NEGREIROS (1527620) in 2019.
# Job 4: The file is from HECTORDAVID OCAMPOSNEGREIROS (1527620) in 2008.
# Job 1: The file is from VICTOR MANUEL PECCI BALART (446027) in 2015.
# Job 2: The file is from VICTOR MANUEL PECCI BALART (446027) in 2016.
# Job 3: The file is from VICTOR MANUEL PECCI BALART (446027) in 2018.
# Job 4: The file is from VICTOR MANUEL PECCHI BALART (446027) in 2013.
# Job 1: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2015.
# Job 2: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2015.
# Job 3: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2016.
# Job 4: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2016.
# Job 5: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2019.
# Job 6: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2020.
# Job 7: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO VDA. DE ASIBEY (232627) in 2020.
# Job 8: The file is from MABEL MIRIAN GLADHYS CAUSARANO VDA DE ASIBEY (232627) in 2013.
# Job 9: The file is from MABEL MIRIAN CAUSARANO DE ASIBEY (232627) in 2013.
# Job 10: The file is from MABEL MIRIAN CAUSARANO DE ASIBEY (232627) in 2014.
# Job 11: The file is from MABEL MIRIAN GLADHYS CAUSARANO GULINO,VDA,DE,ASIBEY (232627) in 2014.
# Job 1: The file is from LADISLAA ALCARAZ DE SILVERO (1164164) in 2018.
# Job 2: The file is from LADISLAA ALCARAZ DE SILVERO (1164164) in 2018.
# Job 3: The file is from LADISLAA ALCARAZ DE SILVERO (1164164) in 2019.
# Job 4: The file is from LADISLAA ALCARAZ DE SILVERO (1164164) in 2019.
# Job 1: The file is from ELADIO RAMON LOIZAGA LEZCANO (316204) in 2016.
# Job 2: The file is from ELADIO RAMON LOIZAGA LEZCANO (316204) in 2018.
# Job 1: The file is from ALEJANDRO FERNANDEZ ROMERO (3569632) in 2016.
# Job 1: The file is from JOAQUIN DANIEL ROA BURGOS (694926) in 2013.
# Job 2: The file is from JOAQUIN DANIEL ROA BURGOS (694926) in 2014.
# Job 1: The file is from JUAN CARLOS LOPEZ MOREIRA (838771) in 2018.
# Job 2: The file is from JUAN CARLOS LOPEZ MOREIRA (838771) in 2014.
# Job 3: The file is from JUANCARLOSROQUE LOPEZMOREIRABORGOGNON (838771) in 2013.
# Job 4: The file is from JUANCARLOSROQUE LOPEZMOREIRABORGOGNON (838771) in 2014.
# Job 1: The file is from RAFAEL AGUILERA MARECO (1123415) in 2017.
# Job 2: The file is from RAFAEL AGUILERA MARECO (1123415) in 2020.
# Job 1: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2018.
# Job 2: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2018.
# Job 3: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2019.
# Job 4: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2019.
# Job 5: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2019.
# Job 6: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2020.
# Job 7: The file is from MARCELAINES BACIGALUPOPLANAS (618781) in 2013.
# Job 8: The file is from MARCELAINES BACIGALUPOPLANAS (618781) in 2014.
# Job 9: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2013.
# Job 10: The file is from MARCELA INES BACIGALUPO DE LEZCANO (618781) in 2014.
# Job 1: The file is from ANA MARIA BAIARDI QUESNEL (725119) in 2018.
# Job 2: The file is from ANA MARIA BAIARDI QUESNEL (725119) in 2018.
# Job 3: The file is from ANAMARIA BAIARDIQUESNEL (725119) in 2013.
# Job 4: The file is from ANAMARIA BAIARDIQUESNEL (725119) in 2014.
# Job 5: The file is from ANA MARIA BAIARDI QUESNEL (725119) in 2013.
# Job 6: The file is from ANA MARIA BAIARDI QUESNEL (725119) in 2014.
# Job 1: The file is from LUIS ALBERTO BOGADO POISSON (402938) in 2015.
# Job 2: The file is from LUIS ALBERTO BOGADO POISSON (402938) in 2013.
# Job 3: The file is from LUIS ALBERTO BOGADO POISSON (402938) in 2014.
# Job 1: The file is from MARIA SOLEDAD QUIÑONEZ ASTIGARRAGA (2102663) in 2015.
# Job 2: The file is from MARIA SOLEDAD QUIÑONEZ ASTIGARRAGA (2102663) in 2018.
# Job 3: The file is from MARIASOLEDAD QUIÑONEZASTIGARRAGA (2102663) in 2006.
# Job 4: The file is from MARIASOLEDAD QUIÑONEZASTIGARRAGA (2102663) in 2012.
# Job 5: The file is from MARIASOLEDAD QUIÑONEZASTIGARRAGA (2102663) in 2013.
# Job 6: The file is from MARIA SOLEDAD QUIÑONEZ ASTIGARRAGA (2102663) in 2004.
# Job 7: The file is from MARIA SOLEDAD QUIÑONEZ ASTIGARRAGA (2102663) in 2012.
# Job 8: The file is from MARIA SOLEDAD QUIÑONEZ ASTIGARRAGA (2102663) in 2013.
# Job 9: The file is from MARIA SOLEDAD QUIÑONEZ ASTIGARRAGA (2102663) in 2014.
# Job 1: The file is from DARIO FILARTIGA RUIZ DIAZ (435101) in 2018.
# Job 2: The file is from DARIO FILARTIGA RUIZ DIAZ (435101) in 2014.
# Job 3: The file is from DARIO FILARTIGA RUIZ DIAZ (435101) in 2000.
# Job 4: The file is from DARIO FILARTIGA RUIZ DIAZ (435101) in 2000.
# Job 5: The file is from DARIO FILARTIGA RUIZ DIAZ (435101) in 2013.
# Job 1: The file is from GUSTAVO ARIEL GILL BARRIOS (3548659) in 2016.
# Job 2: The file is from GUSTAVO ARIEL GILL BARRIOS (3548659) in 2018.
# Job 3: The file is from GUSTAVO ARIEL GILL BARRIOS (3548659) in 2019.
# Job 4: The file is from GUSTAVO ARIEL GILL BARRIOS (3548659) in 2019.
# Job 1: The file is from JUAN PIO IDELIN MOLINAS VEGA (648993) in 2014.
# Job 2: The file is from JUAN PIO IDELIN MOLINAS VEGA (648993) in 2019.
# Job 1: The file is from MÁXIMO DÍAZ CÁCERES (380218) in 2016.
# Job 2: The file is from MÁXIMO DÍAZ CÁCERES (380218) in 2018.
# Job 3: The file is from MAXIMO DIAZ CACERES (380218) in 2014.
# Job 1: The file is from CARLOS ENRIQUE ZÁRATE FLEITAS (2849697) in 2016.
# Job 2: The file is from CARLOS ENRIQUE ZÁRATE FLEITAS (2849697) in 2018.
# Job 3: The file is from CARLOS ENRIQUE ZÁRATE FLEITAS (2849697) in 2020.
# Job 4: The file is from CARLOS ENRIQUE ZARATE FLEITAS (2849697) in 2013.
# Job 5: The file is from CARLOS ENRIQUE ZARATE FLEITAS (2849697) in 2014.
# Job 6: The file is from CARLOS ZARATE FLEITAS (2849697) in 2013.
# Job 1: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 2017.
# Job 2: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 2018.
# Job 3: The file is from OSCARATILIO BOIDANICHFERREIRA (619890) in 2013.
# Job 4: The file is from OSCARATILIO BOIDANICHFERREIRA (619890) in 2014.
# Job 5: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 1993.
# Job 6: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 1996.
# Job 7: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 2011.
# Job 8: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 2013.
# Job 9: The file is from OSCAR ATILIO BOIDANICH FERREIRA (619890) in 2014.
# Job 1: The file is from CLETO LUIS ALBERTO ROJAS RAMIREZ (1467955) in 2019.
# Job 2: The file is from CLETO LUIS ALBERTO ROJAS RAMIREZ (1467955) in 2013.
# Job 3: The file is from CLETO LUIS ALBERTO ROJAS RAMIREZ (1467955) in 2014.
# Job 4: The file is from LUIS ALBERTO ROJAS RAMIREZ (1467955) in 2005.
# Job 1: The file is from MARCELO JAVIER SOTO PAVÓN (1786719) in 2017.
# Job 2: The file is from MARCELO JAVIER SOTO PAVÓN (1786719) in 2018.
# Job 3: The file is from MARCELO JAVIER SOTO PAVÓN (1786719) in 2019.
# Job 1: The file is from luis alberto servin blaires (346742) in 2014.
# Job 2: The file is from luis alberto servin blaires (346742) in 2015.
# Job 3: The file is from luis alberto servin blaires (346742) in 2015.
# Job 4: The file is from luis alberto servin blaires (346742) in 2015.
# Job 5: The file is from luis alberto servin blaires (346742) in 2015.
# Job 6: The file is from luis alberto servin blaires (346742) in 2018.
# Job 7: The file is from LUIS SERVIN BLAIRES (346742) in 1999.
# Job 8: The file is from LUIS SERVIN BLAIRES (346742) in 2003.
# Job 1: The file is from JUAN JOSE CASACCIA FURIASSE (608726) in 2016.
# Job 2: The file is from JUAN JOSE CASACCIA FURIASSE (608726) in 2016.
# Job 3: The file is from JUAN JOSE CASACCIA FURIASSE (608726) in 2017.
# Job 4: The file is from JUAN JOSE CASACCIA FURIASSE (608726) in 2018.
# Job 1: The file is from DIEGO MANUEL SAMANIEGO (3727699) in 2016.
# Job 2: The file is from DIEGO MANUEL SAMANIEGO (3727699) in 2018.
# Job 3: The file is from DIEGO MANUEL SAMANIEGO (3727699) in 2014.
# Job 1: The file is from ROCIO SOLEDAD FLORENTIN GOMEZ (1890292) in 2013.
# Job 2: The file is from ROCIO SOLEDAD FLORENTIN GOMEZ (1890292) in 2014.
# Job 1: The file is from RUBEN DARIO PIRIS FERNANDEZ (923198) in 2016.
# Job 2: The file is from RUBEN DARIO PIRIS FERNANDEZ (923198) in 2016.
# Job 3: The file is from RUBEN DARIO PIRIS FERNANDEZ (923198) in 2019.
# Job 1: The file is from FRANCISCO JOSE DE VARGAS BENITEZ (920868) in 2016.
# Job 2: The file is from FRANCISCO JOSE DE VARGAS BENITEZ (920868) in 1999.
# Job 3: The file is from FRANCISCO JOSE DE VARGAS BENITEZ (920868) in 2013.
# Job 4: The file is from FRANCISCO JOSE,DE,VARGAS,BENITEZ (920868) in 1999.
# Job 5: The file is from FRANCISCO JOSE,DE,VARGAS,BENITEZ (920868) in 2012.
# Job 6: The file is from FRANCISCO JOSE DE VARGAS BENITEZ (920868) in 2013.
# Job 1: The file is from CÍBAR JESÚS EZEQUIEL BENÍTEZ CÁCERES (487021) in 2016.
# Job 2: The file is from CÍBAR JESÚS EZEQUIEL BENÍTEZ CÁCERES (487021) in 2018.
# Job 3: The file is from CÍBAR JESÚS EZEQUIEL BENÍTEZ CÁCERES (487021) in 2019.
# Job 1: The file is from HUGO DAVID VERA QUINTANA (686959) in 2016.
# Job 2: The file is from HUGO DAVID VERA QUINTANA (686959) in 2018.
# Job 3: The file is from HUGO DAVID VERA QUINTANA (686959) in 2002.
# Job 4: The file is from HUGO DAVID VERA QUINTANA (686959) in 2012.
# Job 5: The file is from HUGO DAVID VERA QUINTANA (686959) in 2013.
# Job 1: The file is from FERNANDO LUIS GRIFFITH TORIO (876798) in 2016.
# Job 2: The file is from FERNANDO LUIS GRIFFITH TORIO (876798) in 2018.
# Job 1: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2015.
# Job 2: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2018.
# Job 3: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2018.
# Job 4: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2018.
# Job 5: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2018.
# Job 6: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2018.
# Job 7: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2020.
# Job 8: The file is from CESAR JOSE CARDOZO ROMÁN (835848) in 2020.
# Job 9: The file is from CESAR JOSE CARDOZO ROMAN (835848) in 2013.
# Job 1: The file is from MIGUEL TADEO ROJAS MEZA (902726) in 2016.
# Job 2: The file is from MIGUEL TADEO ROJAS MEZA (902726) in 2018.
# Job 3: The file is from MIGUELTADEO ROJASMEZA (902726) in 2001.
# Job 4: The file is from MIGUELTADEO ROJASMEZA (902726) in 2006.
# Job 5: The file is from MIGUELTADEO ROJASMEZA (902726) in 2006.
# Job 6: The file is from MIGUELTADEO ROJASMEZA (902726) in 2006.
# Job 7: The file is from MIGUELTADEO ROJASMEZA (902726) in 2013.
# Job 8: The file is from MIGUEL TADEO,ROJAS,MEZA (902726) in 1994.
# Job 1: The file is from LORENZO DARIO LEZCANO SANCHEZ (1384728) in 2015.
# Job 2: The file is from LORENZO DARIO LEZCANO SANCHEZ (1384728) in 2017.
# Job 3: The file is from LORENZO DARIO LEZCANO SANCHEZ (1384728) in 2018.
# Job 4: The file is from LORENZO DARIO LEZCANO SANCHEZ (1384728) in 2018.
# Job 5: The file is from LORENZODARIO LEZCANOSANCHEZ (1384728) in 2003.
# Job 6: The file is from LORENZO DARIO LEZCANO SANCHEZ (1384728) in 2003.
# Job 1: The file is from SOFIA MAGALI CACERES CESPEDES (3400701) in 2015.
# Job 2: The file is from SOFIA MAGALI CACERES CESPEDES (3400701) in 2017.
# Job 3: The file is from SOFIA MAGALI CACERES CESPEDES (3400701) in 2018.
# Job 1: The file is from MARIA SOLEDAD NUÑEZ MENDEZ (3382061) in 2014.
# Job 2: The file is from MARIA SOLEDAD NUÑEZ MENDEZ (3382061) in 2018.
# Job 3: The file is from MARIA SOLEDAD NUÑEZ MENDEZ (3382061) in 2018.
# Job 1: The file is from MARIA LORENA MENDEZ DE GUSTAFSON (766742) in 2014.
# Job 2: The file is from MARIA LORENA MENDEZ DE GUSTAFSON (766742) in 2016.
# Job 3: The file is from MARIA LORENA MENDEZ DE GUSTAFSON (766742) in 2016.
# Job 4: The file is from MARIA LORENA MENDEZ DE GUSTAFSON (766742) in 2018.
# Job 1: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2014.
# Job 2: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2017.
# Job 3: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2015.
# Job 4: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2017.
# Job 5: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2017.
# Job 6: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2017.
# Job 7: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2018.
# Job 8: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2019.
# Job 9: The file is from KARINA EVELYN GOMEZ NARVAEZ (3031787) in 2019.
# Job 1: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2015.
# Job 2: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2016.
# Job 3: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2016.
# Job 4: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2016.
# Job 5: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2018.
# Job 6: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2018.
# Job 7: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2018.
# Job 8: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2015.
# Job 9: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2016.
# Job 10: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2016.
# Job 11: The file is from ARIEL MARTINEZ FERNANDEZ (1056514) in 2016.
# Job 1: The file is from LIDUVINO VIELMAN DIAZ (886807) in 2014.
# Job 2: The file is from LIDUVINO VIELMAN DIAZ (886807) in 2020.
# Job 1: The file is from EDGAR EUGENIO RUIZ TORRES (3492337) in 2018.
# Job 1: The file is from JUAN ERNESTO VILLAMAYOR TOMMASI (1431114) in 2018.
# Job 2: The file is from JUAN ERNESTO VILLAMAYOR TOMMASI (1431114) in 2019.
# Job 3: The file is from JUAN ERNESTO VILLAMAYOR TOMMASI (1431114) in 2019.
# Job 1: The file is from DANY EDGAR XAVIER DURAND ESPINOLA (391746) in 2018.
# Job 2: The file is from DANY EDGAR XAVIER DURAND ESPINOLA (391746) in 2019.
# Job 3: The file is from DANY EDGAR XAVIER DURAND ESPINOLA (391746) in 2013.
# Job 1: The file is from JUAN MARCELO ESTIGARRIBIA LÓPEZ (2209022) in 2014.
# Job 2: The file is from JUAN MARCELO ESTIGARRIBIA LÓPEZ (2209022) in 2017.
# Job 3: The file is from JUAN MARCELO ESTIGARRIBIA LÓPEZ (2209022) in 2018.
# Job 4: The file is from JUAN MARCELO ESTIGARRIBIA LOPEZ (2209022) in 2014.
# Job 1: The file is from PORFIRIA TERESA MARTINEZ ACOSTA (770933) in 2015.
# Job 2: The file is from PORFIRIA TERESA MARTINEZ ACOSTA (770933) in 2018.
# Job 3: The file is from PORFIRIA TERESA MARTINEZ ACOSTA (770933) in 2019.
# Job 1: The file is from TERESA DE JESUS ROJAS DE JARA (640913) in 2015.
# Job 2: The file is from TERESA DE JESUS ROJAS DE JARA (640913) in 2018.
# Job 3: The file is from TERESA DE JESUS ROJAS DE JARA (640913) in 2018.
# Job 4: The file is from TERESA DE JESUS ROJAS DE JARA (640913) in 2019.
# Job 5: The file is from TERESA DE JESUS ROJAS DE JARA (640913) in 2019.
# Job 6: The file is from TERESA DE JESUS ROJAS DUARTE (640913) in 2000.
# Job 7: The file is from TERESA DE JESUS ROJAS DUARTE (640913) in 2002.
# Job 8: The file is from TERESA DE JESUS ROJAS JARA (640913) in 2013.
# Job 1: The file is from FELIPE SEBASTIAN SALOMON CASOLA (2352438) in 2018.
# Job 1: The file is from SOFIA ELIZABETH MONTIEL DE AFARA (1217833) in 2018.
# Job 2: The file is from SOFIA MONTIEL DE AFARA (1217833) in 2014.
# Job 1: The file is from CESAR AUGUSTO MARTINEZ FARIÑA (1194695) in 2018.
# Job 2: The file is from CESAR AUGUSTO MARTINEZ FARIÑA (1194695) in 2018.
# Job 3: The file is from CESAR AUGUSTO MARTINEZ FARIÑA (1194695) in 2018.
# Job 1: The file is from ARNALDO EUCLIDES GIUZZIO BENITEZ (1099091) in 2018.
# Job 2: The file is from ARNALDO EUCLIDES GIUZZIO BENITEZ (1099091) in 2018.
# Job 3: The file is from ARNALDO EUCLIDES GIUZZIO BENITEZ (1099091) in 2019.
# Job 4: The file is from ARNALDOEUCLIDES GIUZZIOBENITEZ (1099091) in 2003.
# Job 5: The file is from ARNALDOEUCLIDES GIUZZIOBENITEZ (1099091) in 2004.
# Job 6: The file is from ARNALDOEUCLIDES GIUZZIOBENITEZ (1099091) in 2010.
# Job 7: The file is from ARNALDOEUCLIDES GIUZZIOBENITEZ (1099091) in 2013.
# Job 1: The file is from ALEJANDRO PERALTA VIERCI (1260233) in 2018.
# Job 1: The file is from RUBEN DARIO CAPDEVILA YAMPEY (2513962) in 2018.
# Job 2: The file is from RUBEN DARIO CAPDEVILA YAMPEY (2513962) in 2019.
# Job 3: The file is from RUBEN DARIO CAPDEVILA YAMPEY (2513962) in 2014.
# Job 1: The file is from MIGUEL DAVID JULIAN MARTIN GAONA (2864308) in 2018.
# Job 2: The file is from MIGUEL DAVID JULIAN MARTIN GAONA (2864308) in 2018.
# Job 3: The file is from MIGUEL DAVID JULIAN MARTIN GAONA (2864308) in 2018.
# Job 4: The file is from MIGUEL DAVID JULIAN MARTIN GAONA (2864308) in 2018.
# Job 5: The file is from MIGUEL DAVID JULIAN MARTIN GAONA (2864308) in 2019.
# Job 1: The file is from NIDIA CRISTINA BOGADO DE DOLDAN (905999) in 2018.
# Job 1: The file is from IRMA FÁTIMA MORALES AGUERO (610668) in 2018.
# Job 1: The file is from CARLOS ALBERTO PEREIRA OLMEDO (916313) in 2018.
# Job 2: The file is from CARLOS ALBERTO PEREIRA OLMEDO (916313) in 2018.
# Job 3: The file is from CARLOSALBERTO PEREIRAOLMEDO (916313) in 2014.
# Job 4: The file is from CARLOS ALBERTO PEREIRA OLMEDO (916313) in 2014.
# Job 1: The file is from MARIO JOSÉ GUTIÉRREZ SIMÓN (1742102) in 2018.
# Job 1: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2016.
# Job 2: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2018.
# Job 3: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2018.
# Job 4: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2018.
# Job 5: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2018.
# Job 6: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2018.
# Job 7: The file is from ROQUE ALBERTO SOTELO CHAPARRO (987143) in 2019.
# Job 1: The file is from MARIA CAROLINA LLANES OCAMPOS (852751) in 2015.
# Job 2: The file is from MARIA CAROLINA LLANES OCAMPOS (852751) in 2019.
# Job 3: The file is from MARIA CAROLINA LLANES OCAMPOS (852751) in 2019.
# Job 4: The file is from MARIA CAROLINA LLANES OCAMPOS (852751) in 2016.
# Job 5: The file is from MARIA CAROLINA LLANES OCAMPOS (852751) in 2020.
# Job 1: The file is from RENE MILCIDADES FERNANDEZ BOBADILLA (745882) in 2015.
# Job 2: The file is from RENE MILCIDADES FERNANDEZ BOBADILLA (745882) in 2019.
# Job 3: The file is from RENE MILCIDADES FERNANDEZ BOBADILLA (745882) in 2019.
# Job 4: The file is from RENE MILCIDADES FERNANDEZ BOBADILLA (745882) in 2019.
# Job 5: The file is from RENE MILCIADES FERNANDEZ BOBADILLA (745882) in 2001.
# Job 6: The file is from RENE MILCIADES FERNANDEZ BOBADILLA (745882) in 2013.
# Job 1: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2015.
# Job 2: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2015.
# Job 3: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2015.
# Job 4: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2018.
# Job 5: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2018.
# Job 6: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2019.
# Job 7: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2019.
# Job 8: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2000.
# Job 9: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2004.
# Job 10: The file is from CARLOS ADOLFO ARREGUI ROMERO (1137105) in 2014.
# Job 1: The file is from EUCLIDES ROBERTO ACEVEDO CANDIA (346942) in 2019.
# Job 2: The file is from EUCLIDES ROBERTO ACEVEDO CANDIA (346942) in 2019.
# Job 1: The file is from VIVIANA CASCO MOLINAS (2974481) in 2014.
# Job 2: The file is from VIVIANA CASCO MOLINAS (2974481) in 2015.
# Job 3: The file is from VIVIANA CASCO MOLINAS (2974481) in 2017.
# Job 1: The file is from MARIELA SOLEDAD DE LOS MILAGROS RAMIREZ BURGOS (1362380) in 2015.
# Job 2: The file is from MARIELA SOLEDAD DE LOS MILAGROS RAMIREZ BURGOS (1362380) in 2019.
# Job 3: The file is from MARIELA SOLEDAD DE LOS MILAGROS RAMIREZ BURGOS (1362380) in 2014.
# Job 1: The file is from ZULLY GRACIELA ROLON ESQUIVEL (603957) in 2014.
# Job 2: The file is from ZULLY GRACIELA ROLON ESQUIVEL (603957) in 2018.
# Job 3: The file is from ZULLY GRACIELA ROLON ESQUIVEL (603957) in 2019.
# Job 4: The file is from ZULLY GRACIELA ROLON ESQUIVEL (603957) in 2008.
