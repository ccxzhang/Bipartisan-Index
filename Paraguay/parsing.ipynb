# %%
import os
import pdfplumber

import fitz
fitz.TOOLS.mupdf_display_errors(False) # Ignore the warning

import pandas as pd
import numpy as np

# %% [markdown]
# ## `Class`

# %% [markdown]
# Here are some notices about this class:
#    - As `pdfplumber` can extract texts from well-formatted scanned pdf files, the parsing list only includes files from 2015 or later;
#    - As for files from 2013 and 2014, 2013 files are almost all images, while 2014 has several text files;

# %%
class Extract:
    """
    The `Extract` class is to extract information from pdf files. 
    
    It contains four functions, `generate_parsing_list`, `doubleCheck`, `getTexts`, and `getInfos`.
    
    """
    
    def __init__(self, path, identifier):
        """
        The constructor for Extract class.
        
        Parameters: 
        path (str): The path that stores all the downloaded pdf files.
        identifier (str): vp, cabinet, or legislators
        
        """
         
        self.path= path
        self.identifier= identifier
        self.parsing_list= []
        self.doublecheck_list= []
        self.checked_list= []
        self.txt_paths= []

    def generate_parsing_list(self):

        files= os.listdir(self.path + self.identifier + "/")

        # Check and delete .DS_Store (if exists)
        if ".DS_Store" in files:
            files.remove(".DS_Store")

        # Check each file's year and create the parsing list
        for file in files:
            year= file.split("_")[1]
            if ".pdf" in year:
                year= int(year.replace(".pdf", ""))

                # Check whether the year is later than 2014, because 2013 and 2014 are mixed mode
                if (year > 2014):
                    self.parsing_list.append(file)
                
                # Create a list containing 2013 and 2014 for doublecheck
                if (year== 2013 or year== 2014):             
                    self.doublecheck_list.append(file)
            else:
                
                if (int(year) > 2014):
                    self.parsing_list.append(file)
                    
                if (int(year)== 2013 or int(year)== 2014):
                    self.doublecheck_list.append(file)
            
        
    def doubleCheck(self): 
        """
        The function check the text-page ratio to distinguish the text-format from scanned pdf files.
        
        Returns:
            unparsed: a list of pdf files identified as the scanned pdf files in 2013 and 2014.
        
        """

        for i in self.doublecheck_list: 
                  
            total_page_area= 0.0
            total_text_area= 0.0

            try: 
                checkpath= self.path + self.identifier + "/" + i   
                doc= fitz.open(checkpath) 
                
                for page_num, page in enumerate(doc):
                    
                    total_page_area= total_page_area + abs(page.rect)
                    text_area= 0.0

                    for b in page.getTextBlocks():
                        
                        # Rectangle where block text appears
                        r= fitz.Rect(b[:4])  
                        text_area= text_area + abs(r)
                    
                    # Get the text ratio of the whole page area
                    total_text_area= total_text_area + text_area              
                    text_page_ratio= total_text_area / total_page_area

                # The normal ratio is below 1, and scanned document's ratio usually is larger than 1
                if (text_page_ratio < 1):
                    self.checked_list.append(i)
                        
                doc.close()

            # If EOPError exists, pass the document examination process
            except: 
                continue
        
        unparsed= list(set(self.doublecheck_list)- set(self.checked_list))
                
        return unparsed
                

    def getTexts(self):
        """
        The function is to extract texts from pdf files and to store them in the respective folders.
        
        """
        
        final_list= self.checked_list+ self.parsing_list
        
        for i in final_list:
            try:
                filepath= self.path + self.identifier + "/" + i
                pdf= pdfplumber.open(filepath)

                # Extract the each line of each page of the pdf files
                # Set the x-/y- tolerance as 4 (defacult as 3) to include more distant texts             
                texts= []
                for page in pdf.pages:
                    texts.append(page.extract_text(x_tolerance=4, y_tolerance=4).splitlines())

                output_path= ('/Users/charliezhang/Dropbox/disclosures-data/Charlie-Zhang/Paraguay/output/'
                                + self.identifier + "/")
                
                if not os.path.exists(output_path):
                    os.makedirs(output_path)

                txt_path= output_path + i.replace(".pdf", ".txt")
                
                # Store the txt file as part of the output
                with open(txt_path, "w") as f:
                    for page in texts:
                        for line in page:
                            f.write(line + "\n")
                
                self.txt_paths.append(txt_path)
                         

            except:
                print(i+ " cannot be parsed. Because it could be an image.")
                
    
    def getInfos(self):
        
        """
        The function is to read texts from intermediate txt files.
        
        Returns:
            infos: a dictionary can easily transformed to the DataFrame. 
        
        """
        reason= []
        personid= []
        dates= []
        first= []
        last= []
        dob= []
        marital_status= []
        educ=[]
        academic= []
        institutions= []
        departments= []
        positions= []
        deposits= []
        vehicles= []
        immoveables= []
        moveables=[]
        cattle_crops= []
        debts= []
        monthly_incomes= []
        annual_incomes= []
        
        
        # List the files in the assigned directory -> produce the absolute path for reading
        output_path= ('/Users/charliezhang/Dropbox/disclosures-data/Charlie-Zhang/Paraguay/output/'
                                + self.identifier + "/")
        
        relative_path= os.listdir(output_path)
        
        if ".DS_Store" in relative_path: 
            relative_path.remove(".DS_Store")
            
        txtpaths= [output_path+ i for i in relative_path]
        
        for i in txtpaths:
            with open(i, "r") as f:
                doc= f.read().splitlines()
                
                # Create lists to store matched lines
                date_lines= []
                name_lines= []
                institution_lines= []
                academic_lines= []
                department_lines= []
                position_lines= []

                deposit_lines= []
                vehicle_lines= []
                moveable_lines= []
                immoveable_lines= []
                cattle_crop_lines= []
                debt_lines= []
                monthly_income_lines= []
                annual_income_lines= []

                for index, line in enumerate(doc):
                    
                    # Use index to restrict multiple matches
                    # Often, it is the second/third line of the first page
                    if index < 5 and line.find("MOTIVO DE LA") != -1:
                        motive= line.replace("MOTIVO DE LA", "")
                        reason.append(motive.strip())

                    if line.find("RECEPCIONADO") != -1:
                        date_lines.append(line)

                    ## Use two position to check to aviod mismatching
                    if line.find("CÉDULA DE") != -1 and line.find("RUC")!= -1:
                        if line.find("IDENTIDAD") != -1: 
                            id= line.replace("CÉDULA DE IDENTIDAD:", "").replace("RUC", "").split(":")
                            personid.append(id[0].strip())
                        
                        else:
                            id= line.replace("CÉDULA DE", "").replace("RUC", "").split(":")
                            personid.append(id[0].strip())

                    # Use first and last name to restrict other matches
                    if line.find("NOMBRE:") != -1 and line.find("APELLIDOS") != -1:
                        name_lines.append(line)

                    if line.find("FECHA DE NAC.") != -1:
                        birth= line.replace("FECHA DE NAC.: ", "").replace("NACIONALIDAD", "").split(":")
                        dob.append(birth[0].strip())

                    if line.find("ESTADO CIVIL") != -1:
                        marital= line.replace("ESTADO CIVIL: ", "").replace("CELULAR 2", "").split(":")
                        marital_status.append(marital[0].strip())

                    if line.find("E MAIL") != -1 and line.find("GRADO ACADEM") != -1:
                        education= line.split(":")
                        educ.append(education[2].strip())        

                    if line.find("TITULO OBTENIDO") != -1:
                        academic_lines.append(line)

                    if line.find("INSTITUCIÓN:") != -1 and line.find("DIRECCIÓN") != -1:
                        institution_lines.append(line)

                    if line.find("TIPO") != -1 and line.find("DEPENDENCIA") != -1 :
                        department_lines.append(line)

                    if line.find("CARGO") != -1 and line.find("CATEGORÍA") != -1:
                        position_lines.append(line)

                    if line.find("TOTAL DEPÓSITOS:") != -1:
                        deposit_lines.append(line)

                    if line.find("TOTAL INMUEBLES:") != -1:
                        immoveable_lines.append(line)

                    if line.find("TOTAL MUEBLES:") != -1:
                        moveable_lines.append(line)

                    if line.find("TOTAL VEHÍCULOS:") != -1:
                        vehicle_lines.append(line)

                    if line.find("TOTAL ACTIVIDAD") != -1:
                        cattle_crop_lines.append(line)

                    if line.find("TOTALE") != -1:
                        debt_lines.append(line)
                        
                    if line.find("TOTAL INGRESOS MENSUALES") != -1:
                        monthly_income_lines.append(line)

                    if line.find("TOTAL INGRESOS ANUALES") != -1:
                        annual_income_lines.append(line)

                
                if len(date_lines) != 0:
                    if "RECEPCIONADO EL" in date_lines[0]:
                        date= date_lines[0].split(": ")[-1].split(" ")[0]
                        dates.append(date.strip())
                    else: 
                        date= date_lines[0].split(" ")[-2]
                        dates.append(date.strip())

                if len(name_lines) != 0:
                    name= name_lines[0].replace("NOMBRE: ", "").replace("APELLIDOS", "").split(":")
                    first.append(name[0].strip())
                    last.append(name[1].strip())

                
                if len(institution_lines) != 0:
                    inst_strs= ""
            
                    for line in institution_lines:            
                        institution= line.replace("INSTITUCIÓN:", "").replace("DIRECCIÓN", "").split(":")
                        inst= institution[0].strip() + " "
                        inst_strs += inst
                    institutions.append(inst_strs)
                    
                else: 
                    institutions.append(np.NaN)

                
                if len(department_lines) != 0:              
                    dept_strs= ""

                    for index, line in enumerate(department_lines):
                        department= line.replace("TELÉFONO", "").split(":")
                        dept= str(index+1) + ": " + department[2].strip() + " "
                        dept_strs += dept

                    departments.append(dept_strs)
            
                else:
                    departments.append(np.NaN)

                
                if len(position_lines) != 0:
                    posn_strs= ""

                    for index, line in enumerate(position_lines):
                        position= line.split(":")[-1]
                        posn= str(index+1) + ": " + position.strip() + " "
                        posn_strs += posn 

                    positions.append(posn_strs)
                
                else:
                    positions.append(np.NaN)
                
                
                ## If one has academic title, get it; else, return np.nan
                if len(academic_lines) == 0:
                    academic.append(np.NaN)                 
                
                else:
                    title= line.replace("TITULO OBTENIDO:", "")        
                    if bool(title and title.strip())== True:
                        academic.append(np.NaN)
                    else: 
                        academic.append(title[-1])

                if len(deposit_lines) != 0:
                    deposit= deposit_lines[-1].replace("TOTAL DEPÓSITOS:", "")
                    deposits.append(deposit.strip())
                else: 
                    deposits.append(np.NaN)


                if len(vehicle_lines) != 0:
                    vehicle= vehicle_lines[-1].replace("TOTAL VEHÍCULOS:", "")
                    vehicles.append(vehicle.strip())
                    
                else:
                    vehicles.append(np.NaN)

                if len(immoveable_lines) != 0:
                    immoveable= immoveable_lines[-1].replace("TOTAL INMUEBLES:", "")
                    immoveables.append(immoveable.strip())
                else: 
                    immoveables.append(np.NaN)

                if len(moveable_lines) != 0:
                    moveable= moveable_lines[-1].replace("TOTAL MUEBLES:", "")
                    moveables.append(moveable.strip())
                else:
                    moveables.append(np.NaN)

                if len(cattle_crop_lines) == 0:
                    cattle_crops.append(np.NaN)
                else:
                    cattle_crop= cattle_crop_lines[-1].replace("TOTAL ACTIVIDAD", "")
                    cattle_crops.append(cattle_crop.strip())

                if len(debt_lines) != 0:
                    debt= debt_lines[-1].split(" ")[-1]
                    debts.append(debt.strip())
                else:
                    debts.append(np.NaN)

                if len(monthly_income_lines) != 0:
                    monthly_income= monthly_income_lines[-1].replace("TOTAL INGRESOS MENSUALES", "")
                    monthly_incomes.append(monthly_income.strip())
                else: 
                    monthly_incomes.append(np.NaN)


                if len(annual_income_lines) != 0:
                    annual_income= annual_income_lines[-1].replace("TOTAL INGRESOS ANUALES", "")
                    annual_incomes.append(annual_income.strip())
                else: 
                    annual_incomes.append(np.NaN)



        # Compile the dictionary
        info= {"reason": reason,
               "id": personid,
               "date": dates,
               "first": first,
               "last": last,
               "dob": dob,
               "marital": marital_status,
               "educ": educ,
               "academic": academic,
               "institution": institutions,
               "department": departments,
               "position": positions,
               "deposit": deposits,
               "immoveable": immoveables,
               "vehicle": vehicles,
               "cattle_crop": cattle_crops,
               "moveable": moveables,
               "debt": debts,
               "income_month": monthly_incomes,
               "income_annual": annual_incomes}
        return info

# %%
help(Extract)
# Out:
# Help on class Extract in module __main__:
#
# class Extract(builtins.object)
#  |  Extract(path, identifier)
#  |
#  |  The `Extract` class is to extract information from pdf files.
#  |
#  |  It contains four functions, `generate_parsing_list`, `doubleCheck`, `getTexts`, and `getInfos`.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, path, identifier)
#  |      The constructor for Extract class.
#  |
#  |      Parameters:
#  |      path (str): The path that stores all the downloaded pdf files.
#  |      identifier (str): vp, cabinet, or legislators
#  |
#  |  doubleCheck(self)
#  |      The function check the text-page ratio to distinguish the text-format from scanned pdf files.
#  |
#  |      Returns:
#  |          unparsed: a list of pdf files identified as the scanned pdf files in 2013 and 2014.
#  |
#  |  generate_parsing_list(self)
#  |
#  |  getInfos(self)
#  |      The function is to read texts from intermediate txt files.
#  |
#  |      Returns:
#  |          infos: a dictionary can easily transformed to the DataFrame.
#  |
#  |  getTexts(self)
#  |      The function is to extract texts from pdf files and to store them in the respective folders.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ## VP

# %%
vp= Extract(path= "/Users/charliezhang/Dropbox/disclosures-data/Charlie-Zhang/Paraguay/data/",
            identifier= "vp")
vp.generate_parsing_list()
vp_unparsed_1314= vp.doubleCheck()
vp.getTexts()

# %%
vp_infos= pd.DataFrame(vp.getInfos())
vp_infos= vp_infos.sort_values(by = "id").reset_index().drop(columns= "index")

# %%
vp_infos
# Out:
#               reason      id        date           first  \
# 0  ASUNCION AL CARGO  352252  11/05/2018  ALICIA BEATRIZ
# 1     BAJA DEL CARGO  352252  17/08/2018  ALICIA BEATRIZ
# 2     BAJA DEL CARGO  352252  09/05/2018  ALICIA BEATRIZ
# 3               OTRO  652236  27/06/2014      JUAN EUDES
# 4  ASUNCION AL CARGO  652236  12/07/2018      JUAN EUDES
# 5     BAJA DEL CARGO  652236  26/04/2018      JUAN EUDES
# 6     BAJA DEL CARGO  832988  24/07/2017  HUGO ADALBERTO
# 7               OTRO  832988  05/05/2020  HUGO ADALBERTO
# 8  ASUNCION AL CARGO  832988  30/08/2018  HUGO ADALBERTO
# 9     BAJA DEL CARGO  832988  18/04/2018  HUGO ADALBERTO
#
#                     last         dob                            marital  \
# 0  PUCHETA VDA DE CORREA  14/01/1950                            VIUDO/A
# 1  PUCHETA VDA DE CORREA  14/01/1950                            VIUDO/A
# 2  PUCHETA VDA DE CORREA  14/01/1950                            VIUDO/A
# 3           AFARA MACIEL  19/08/1960  CASADO/A SIN SEPARACION DE BIENES
# 4           AFARA MACIEL  19/08/1960  CASADO/A SIN SEPARACION DE BIENES
# 5           AFARA MACIEL  19/08/1960  CASADO/A SIN SEPARACION DE BIENES
# 6       VELAZQUEZ MORENO  03/09/1967  CASADO/A CON SEPARACION DE BIENES
# 7       VELAZQUEZ MORENO  03/09/1967  CASADO/A CON SEPARACION DE BIENES
# 8       VELAZQUEZ MORENO  03/09/1967  CASADO/A CON SEPARACION DE BIENES
# 9       VELAZQUEZ MORENO  03/09/1967  CASADO/A CON SEPARACION DE BIENES
#
#         educ  academic                                        institution  \
# 0  TERCIARIO       NaN  2 UNIVERSIDAD NACIONAL DE ASUNCION 3 VICEPRESI...
# 1  TERCIARIO       NaN  2 UNIVERSIDAD NACIONAL DE ASUNCION 3 VICEPRESI...
# 2  TERCIARIO       NaN  1 CORTE SUPREMA DE JUSTICIA 3 UNIVERSIDAD NACI...
# 3  TERCIARIO       NaN                 1 VICEPRESIDENCIA DE LA REPUBLICA
# 4  TERCIARIO       NaN                   1 HONORABLE CAMARA DE SENADORES
# 5  TERCIARIO       NaN                 1 VICEPRESIDENCIA DE LA REPUBLICA
# 6  TERCIARIO       NaN                   1 HONORABLE CAMARA DE DIPUTADOS
# 7  TERCIARIO       NaN                 1 VICEPRESIDENCIA DE LA REPUBLICA
# 8  TERCIARIO       NaN                 1 VICEPRESIDENCIA DE LA REPUBLICA
# 9  TERCIARIO       NaN                   1 HONORABLE CAMARA DE DIPUTADOS
#
#                                           department  \
# 0         1: FACULTAD DE DERECHO 2: VICEPRESIDENCIA
# 1         1: FACULTAD DE DERECHO 2: VICEPRESIDENCIA
# 2  1: MINISTRA DE LA CORTE SUPREMA DE JUSTICIA 2:...
# 3                               1: VICE PRESIDENCIA
# 4                            1: SENADO DE LA NACIÓN
# 5                               1: VICE PRESIDENCIA
# 6                              1: DIPUTADO NACIONAL
# 7                                1: VICEPRESIDENCIA
# 8                                1: VICEPRESIDENCIA
# 9                            1: CAMARA DE DIPUTADOS
#
#                                             position        deposit  \
# 0                      1: DOCENTE 2: VICEPRESIDENTA      22,000,234
# 1                      1: DOCENTE 2: VICEPRESIDENTA      22,000,234
# 2  1: MINISTRO DE LA CORTE SUPREMA DE JUSTICIA 2:...     22,000,234
# 3                 1: VICEPRESIDENTE DE LA REPÚBLICA     825,000,000
# 4                               1: SENADOR NACIONAL     380,314,869
# 5                 1: VICEPRESIDENTE DE LA REPÚBLICA   1,218,988,384
# 6  1: CESE PRESIDENCIA DE LA H. CAMARA DE DIPUTADOS       5,907,651
# 7                 1: VICEPRESIDENTE DE LA REPÚBLICA         344,000
# 8                 1: VICEPRESIDENTE DE LA REPÚBLICA         344,000
# 9                              1: DIPUTADO NACIONAL         526,446
#
#       immoveable      vehicle    cattle_crop     moveable           debt  \
# 0  1,650,000,000  177,000,000            NaN  970,000,000     20,493,849
# 1  1,650,000,000  177,000,000            NaN  970,000,000     43,420,137
# 2  1,650,000,000  177,000,000            NaN  970,000,000     20,493,849
# 3  8,540,700,000  398,800,000    970,100,000  350,000,000  2,392,000,000
# 4  8,590,000,000  396,550,000  1,171,000,000  350,000,000  2,399,248,000
# 5  8,590,000,000  396,550,000  1,171,000,000  350,000,000  2,458,314,687
# 6    938,708,000  910,816,795            NaN  162,364,635    297,106,617
# 7    938,708,000  919,442,639            NaN  172,864,635    283,820,373
# 8    938,708,000  919,442,639            NaN  172,864,635    283,820,373
# 9    938,708,000  910,816,795            NaN  162,364,635    234,061,333
#
#   income_month  income_annual
# 0   46,497,794     57,572,661
# 1   46,497,794     57,572,661
# 2   57,572,661     57,572,661
# 3   91,163,080  2,855,257,975
# 4   87,774,840  2,851,869,735
# 5   90,927,900  2,855,257,975
# 6   37,076,740  8,835,658,985
# 7   32,000,000    625,500,000
# 8   32,000,000    625,500,000
# 9   37,076,740    798,597,200

# %%
vp_infos.to_csv("vp_infos.csv")

# %% [markdown]
# ## Cabinet

# %%
cab= Extract(path= "/Users/charliezhang/Dropbox/disclosures-data/Charlie-Zhang/Paraguay/data/",
            identifier= "cabinet")
cab.generate_parsing_list()
cab_unparsed_1314= cab.doubleCheck()
cab.getTexts()

# %%
cab_unparsed_1314
# Out:
# ['640913_2013.pdf',
#  '916313_2014_1.pdf',
#  '1047386_2014.pdf',
#  '835848_2013.pdf',
#  '838771_2014_1.pdf',
#  '2102663_2014.pdf',
#  '1699606_2014.pdf',
#  '446027_2013.pdf',
#  '618781_2013_1.pdf',
#  '1047386_2014_1.pdf',
#  '453913_2013.pdf',
#  '725119_2014_1.pdf',
#  '725119_2013.pdf',
#  '916313_2014.pdf',
#  '1217833_2014.pdf',
#  '1362380_2014.pdf',
#  '1388499_2013_1.pdf',
#  '1890292_2013.pdf',
#  '409636_2013.pdf',
#  '232663_2013_1.pdf',
#  '920868_2013_1.pdf',
#  '694926_2013.pdf',
#  '1047386_2013_1.pdf',
#  '2849697_2013_1.pdf',
#  '232627_2013.pdf',
#  '1467955_2013.pdf',
#  '619890_2013_1.pdf',
#  '232627_2014.pdf',
#  '1699606_2013.pdf',
#  '232663_2013_2.pdf',
#  '920868_2013.pdf',
#  '380218_2014.pdf',
#  '1890292_2014.pdf',
#  '694926_2014.pdf',
#  '745882_2013.pdf',
#  '1137105_2014.pdf',
#  '618781_2014_1.pdf',
#  '1388499_2013.pdf',
#  '619890_2013.pdf',
#  '1467955_2014.pdf',
#  '2849697_2013.pdf',
#  '725119_2014.pdf',
#  '902726_2013.pdf',
#  '1047386_2013.pdf',
#  '402938_2014.pdf',
#  '618781_2013.pdf',
#  '435101_2013.pdf',
#  '619890_2014.pdf',
#  '686959_2013.pdf',
#  '2849697_2014.pdf',
#  '2513962_2014.pdf',
#  '3727699_2014.pdf',
#  '618781_2014.pdf',
#  '219847_2013_1.pdf',
#  '619890_2014_1.pdf',
#  '2102663_2013.pdf',
#  '838771_2013.pdf',
#  '402938_2013.pdf',
#  '725119_2013_1.pdf',
#  '1099091_2013.pdf',
#  '2102663_2013_1.pdf',
#  '232627_2014_1.pdf',
#  '913111_2014.pdf',
#  '992145_2014.pdf',
#  '391746_2013.pdf',
#  '219847_2013.pdf',
#  '232663_2013.pdf',
#  '2209022_2014_1.pdf',
#  '232627_2013_1.pdf']

# %%
cab_infos= pd.DataFrame(cab.getInfos())

# %%
for key, value in cab.getInfos().items():
    print(key, len(value))
# Out:
# reason 206
# id 206
# date 206
# first 206
# last 206
# dob 206
# marital 206
# educ 206
# academic 206
# institution 206
# department 206
# position 206
# deposit 206
# immoveable 206
# vehicle 206
# cattle_crop 206
# moveable 206
# debt 206
# income_month 206
# income_annual 206

# %%
cab_infos= cab_infos.sort_values(by = "id").reset_index().drop(columns= "index")

# %%
cab_infos
# Out:
#                               reason       id        date           first  \
# 0                     BAJA DEL CARGO  1047386  22/08/2018  HUMBERTO RUBEN
# 1    PRESENTACIÓN: ASUNCION AL CARGO  1056514  30/11/2016           ARIEL
# 2    PRESENTACIÓN: ASUNCION AL CARGO  1056514  30/11/2016           ARIEL
# 3        PRESENTACIÓN: Actualizacion  1056514  13/05/2015           ARIEL
# 4                               OTRO  1056514  13/05/2015           ARIEL
# ..                               ...      ...         ...             ...
# 201                             OTRO   987143  29/08/2019   ROQUE ALBERTO
# 202                             OTRO   987143  19/11/2018   ROQUE ALBERTO
# 203                             OTRO   987143  29/11/2016   ROQUE ALBERTO
# 204                   BAJA DEL CARGO   992145  21/08/2018        FABRIZIO
# 205                             OTRO   992145  08/02/2016        FABRIZIO
#
#                    last         dob                            marital  \
# 0      PERALTA BEAUFORT  22/01/1971  CASADO/A CON SEPARACION DE BIENES
# 1    MARTINEZ FERNANDEZ  30/03/1979                          SOLTERO/A
# 2    MARTINEZ FERNANDEZ  30/03/1979                          SOLTERO/A
# 3    MARTINEZ FERNANDEZ  30/03/1979                          SOLTERO/A
# 4    MARTINEZ FERNANDEZ  30/03/1979                          SOLTERO/A
# ..                  ...         ...                                ...
# 201     SOTELO CHAPARRO  06/05/1967  CASADO/A SIN SEPARACION DE BIENES
# 202     SOTELO CHAPARRO  06/05/1967  CASADO/A SIN SEPARACION DE BIENES
# 203     SOTELO CHAPARRO  06/05/1967  CASADO/A SIN SEPARACION DE BIENES
# 204     CALIGARIS RAMOS  05/05/1976  CASADO/A CON SEPARACION DE BIENES
# 205     CALIGARIS RAMOS  05/05/1976  CASADO/A CON SEPARACION DE BIENES
#
#           educ  academic                                        institution  \
# 0    TERCIARIO       NaN                1 SECRETARIA DE LA FUNCION PUBLICA
# 1    TERCIARIO       NaN  1 MINISTERIO DEL INTERIOR 2 MINISTERIO PUBLICO...
# 2    TERCIARIO       NaN  1 MINISTERIO DEL INTERIOR 2 MINISTERIO PUBLICO...
# 3    TERCIARIO       NaN  1 MINISTERIO PUBLICO FISCALIA GENERAL DEL ESTADO
# 4    TERCIARIO       NaN  1 MINISTERIO PUBLICO FISCALIA GENERAL DEL ESTADO
# ..         ...       ...                                                ...
# 201  TERCIARIO       NaN  1 COMANDO DE LAS FUERZAS MILITARES 2 PRESIDENC...
# 202  TERCIARIO       NaN                1 COMANDO DE LAS FUERZAS MILITARES
# 203  TERCIARIO       NaN                  1 MINISTERIO DE DEFENSA NACIONAL
# 204  TERCIARIO       NaN                     1 PRESIDENCIA DE LA REPUBLICA
# 205  TERCIARIO       NaN                     1 PRESIDENCIA DE LA REPUBLICA
#
#                                             department  \
# 0                                1: DESPACHO MINISTRO
# 1    1: VICE MINISTERIO DE ASUNTOS POLITICOS 2: DEL...
# 2    1: VICE MINISTERIO DE ASUNTOS POLITICOS 2: DEL...
# 3                             1: DELITOS INFORMATICOS
# 4                             1: DELITOS INFORMATICOS
# ..                                                 ...
# 201           1: GABINETE MILITAR 2: GABINETE MILITAR
# 202                               1: GABINETE MILITAR
# 203                   1: FUERZAS ARMADAS DE LA NACION
# 204       1: SECRETARIA DE INFORMACION Y COMUNICACION
# 205       1: SECRETARIA DE INFORMACION Y COMUNICACION
#
#                                               position      deposit  \
# 0                             1: SECRETARIO EJECUTIVO           NaN
# 1    1: VICEMINISTRO DEL PODER EJECUTIVO 2: AGENTE ...    5.000.000
# 2    1: VICEMINISTRO DEL PODER EJECUTIVO 2: AGENTE ...    5.000.000
# 3                                    1: AGENTE FISCAL    20.823.736
# 4                                    1: AGENTE FISCAL    20,823,736
# ..                                                 ...          ...
# 201  1: MINISTRO JEFE DEL GABINETE MILITAR 2: MINIS...  110,000,000
# 202             1: MINISTRO JEFE DEL GABINETE MILITAR   442,000,000
# 203    1: AGREGADO DE DEFENSA DE PARAGUAY EN ALEMANIA   442,000,000
# 204                           1: SECRETARIO EJECUTIVO   421,920,638
# 205                           1: SECRETARIO EJECUTIVO   283,933,057
#
#         immoveable      vehicle cattle_crop     moveable         debt  \
# 0              NaN          NaN         NaN  225,000,000  106,500,000
# 1    1.250.000.000          NaN         NaN  165.000.000          NaN
# 2    1.250.000.000          NaN         NaN  165.000.000          NaN
# 3    1.250.000.000        100.0         NaN  150.000.000          NaN
# 4    1,250,000,000      100,000         NaN  150,000,000          NaN
# ..             ...          ...         ...          ...          ...
# 201  1,630,000,000  165,000,000         NaN  136,000,000   43,844,796
# 202    730,000,000   90,000,000         NaN   81,000,000   71,286,000
# 203    730,000,000   90,000,000         NaN   81,000,000   71,286,000
# 204  3,600,000,000  330,045,030         NaN  250,000,000  113,400,000
# 205  3,600,000,000  502,020,000         NaN  250,000,000          NaN
#
#     income_month income_annual
# 0     42,851,200    24,851,200
# 1     24.693.600           NaN
# 2     24.693.600           NaN
# 3     20.327.600    20.327.600
# 4     20,327,600    20,327,600
# ..           ...           ...
# 201   34,970,310    25,151,200
# 202   52,900,000    39,500,000
# 203   52,900,000    39,500,000
# 204   39,851,200           NaN
# 205   39,851,200           NaN
#
# [206 rows x 20 columns]

# %%
cab_infos.to_csv("cabinet_infos.csv")

# %% [markdown]
# ## Legislators

# %%
legis= Extract(path= "/Users/charliezhang/Dropbox/disclosures-data/Charlie-Zhang/Paraguay/data/",
            identifier= "legislators")
legis.generate_parsing_list()
legis_unparsed_1314= legis.doubleCheck()

# %%
legis.getTexts()
# Out:
# 1094794_2014_1.pdf cannot be parsed. Because it could be an image.
# 95732_2018.pdf cannot be parsed. Because it could be an image.
# 1163876_2020.pdf cannot be parsed. Because it could be an image.

# %%
legis_info= legis.getInfos()

# %%
for key, value in legis_info.items():
    print(key, ":", len(value))
# Out:
# reason : 614
# id : 614
# date : 614
# first : 614
# last : 614
# dob : 614
# marital : 614
# educ : 614
# academic : 614
# institution : 614
# department : 614
# position : 614
# deposit : 614
# immoveable : 614
# vehicle : 614
# cattle_crop : 614
# moveable : 614
# debt : 614
# income_month : 614
# income_annual : 614

# %%
legis_infos= pd.DataFrame(legis_info)

# %%
legis_infos= legis_infos.sort_values(by = "id").reset_index().drop(columns= "index")

# %%
legis_infos
# Out:
#                                         reason       id        date  \
# 0    PRESENTACIÓN: RECTIFICATIVA DJ 16-07-2018  1000687  08/05/2020
# 1                                         OTRO  1000687  08/05/2020
# 2                                         OTRO  1000687  08/05/2020
# 3    PRESENTACIÓN: RECTIFICATIVA DJ 29-10-2012  1000687  08/05/2020
# 4    PRESENTACIÓN: RECTIFICATIVA DJ 19-07-2013  1000687  08/05/2020
# ..                                         ...      ...         ...
# 609                          ASUNCION AL CARGO   989122  11/09/2017
# 610                          ASUNCION AL CARGO   989122  15/07/2018
# 611                             BAJA DEL CARGO   989122  28/09/2018
# 612                             BAJA DEL CARGO   989122  25/01/2018
# 613                          ASUNCION AL CARGO   990058  13/07/2018
#
#               first                last         dob  \
# 0    ENRIQUE FAUSTO  BACCHETTA CHIRIANI  15/07/1967
# 1    ENRIQUE FAUSTO  BACCHETTA CHIRIANI  15/07/1967
# 2    ENRIQUE FAUSTO  BACCHETTA CHIRIANI  15/07/1967
# 3    ENRIQUE FAUSTO  BACCHETTA CHIRIANI  15/07/1967
# 4    ENRIQUE FAUSTO  BACCHETTA CHIRIANI  15/07/1967
# ..              ...                 ...         ...
# 609   JORGE ANTONIO        OVIEDO MATTO  13/06/1966
# 610   JORGE ANTONIO        OVIEDO MATTO  13/06/1966
# 611   JORGE ANTONIO        OVIEDO MATTO  13/06/1966
# 612   JORGE ANTONIO        OVIEDO MATTO  13/06/1966
# 613          EMILIO        PAVON DOLDAN  17/12/1966
#
#                                marital       educ  academic  \
# 0    CASADO/A SIN SEPARACION DE BIENES  TERCIARIO       NaN
# 1    CASADO/A SIN SEPARACION DE BIENES  TERCIARIO       NaN
# 2    CASADO/A SIN SEPARACION DE BIENES  TERCIARIO       NaN
# 3    CASADO/A SIN SEPARACION DE BIENES  TERCIARIO       NaN
# 4    CASADO/A SIN SEPARACION DE BIENES  TERCIARIO       NaN
# ..                                 ...        ...       ...
# 609  CASADO/A CON SEPARACION DE BIENES  TERCIARIO       NaN
# 610  CASADO/A CON SEPARACION DE BIENES  TERCIARIO       NaN
# 611  CASADO/A CON SEPARACION DE BIENES  TERCIARIO       NaN
# 612  CASADO/A CON SEPARACION DE BIENES  TERCIARIO       NaN
# 613  CASADO/A SIN SEPARACION DE BIENES  TERCIARIO       NaN
#
#                           institution                      department  \
# 0    1 HONORABLE CAMARA DE SENADORES          1: CAMARA DE SENADORES
# 1    1 HONORABLE CAMARA DE SENADORES          1: CAMARA DE SENADORES
# 2    1 HONORABLE CAMARA DE SENADORES          1: CAMARA DE SENADORES
# 3       1 CONSEJO DE LA MAGISTRATURA   1: CONSEJO DE LA MAGISTRATURA
# 4    1 HONORABLE CAMARA DE SENADORES          1: CAMARA DE SENADORES
# ..                                ...                             ...
# 609  1 HONORABLE CAMARA DE SENADORES      1: VICEPRESIDENCIA PRIMERA
# 610  1 HONORABLE CAMARA DE SENADORES         1: SENADOR DE LA NACION
# 611  1 HONORABLE CAMARA DE SENADORES         1: SENADOR DE LA NACION
# 612  1 HONORABLE CAMARA DE SENADORES      1: VICEPRESIDENCIA PRIMERA
# 613              1 CONGRESO NACIONAL             1: CONGRESO NACINAL
#
#                                               position     deposit  \
# 0                                 1: SENADOR NACIONAL   73.942.496
# 1                                 1: SENADOR NACIONAL   49,637,265
# 2                                 1: SENADOR NACIONAL   73,942,496
# 3    1: PRESIDENTE O MIEMBRO DEL CONSEJO DE LA MAGI...  48.043.098
# 4                                 1: SENADOR NACIONAL   49.637.265
# ..                                                 ...         ...
# 609                               1: SENADOR NACIONAL   27,000,000
# 610                           1: SENADOR DE LA NACION   41,718,760
# 611                           1: SENADOR DE LA NACION      818,031
# 612                               1: SENADOR NACIONAL    3,396,075
# 613                                       1: DIPUTADO   73,725,997
#
#         immoveable      vehicle  cattle_crop     moveable           debt  \
# 0    3.042.664.128   39.460.000          NaN  895.000.000  1.879.230.319
# 1    1,904,636,642  201,160,000          NaN  895,000,000    206,380,581
# 2    3,042,664,128   39,460,000          NaN  895,000,000  1,879,230,319
# 3    1.904.636.642  201.160.000          NaN  895.000.000    108.543.947
# 4    1.904.636.642  201.160.000          NaN  895.000.000    206.380.581
# ..             ...          ...          ...          ...            ...
# 609  1,395,750,000  474,397,000          NaN   60,000,000      3,202,609
# 610  3,085,750,000  474,397,000          NaN   60,000,000     73,273,291
# 611  3,325,750,000  390,000,000          NaN   60,000,000     63,298,164
# 612  3,085,750,000  474,397,000          NaN   60,000,000      1,597,029
# 613  1,534,000,000  265,000,000  109,150,000          NaN    260,580,000
#
#     income_month income_annual
# 0     54.759.872   896.273.382
# 1     78,569,395   351,045,872
# 2     54,759,872   896,273,382
# 3     62.740.648   540.000.000
# 4     78.569.395   351.045.872
# ..           ...           ...
# 609   72,273,392   532,724,840
# 610   52,000,000           NaN
# 611   79,530,865   240,000,000
# 612   70,649,398    33,940,888
# 613   61,042,196   176,400,000
#
# [614 rows x 20 columns]

# %%
legis_infos.to_csv("legislators_infos.csv")

# %%
legis_unparsed_1314
# Out:
# ['753777_2013.pdf',
#  '660812_2013.pdf',
#  '650349_2013.pdf',
#  '2188426_2013.pdf',
#  '571502_2013.pdf',
#  '1412612_2013.pdf',
#  '981087_2013.pdf',
#  '384004_2013.pdf',
#  '481344_2013.pdf',
#  '3984772_2013_1.pdf',
#  '2480063_2013.pdf',
#  '1009116_2013.pdf',
#  '738164_2013.pdf',
#  '380566_2013.pdf',
#  '2846714_2013.pdf',
#  '488492_2013.pdf',
#  '1378996_2013_2.pdf',
#  '875792_2013.pdf',
#  '736233_2013.pdf',
#  '719614_2013.pdf',
#  '2952067_2013.pdf',
#  '1255411_2013.pdf',
#  '280307_2013.pdf',
#  '1843567_2013.pdf',
#  '1464359_2013.pdf',
#  '1054280_2013.pdf',
#  '1115731_2013.pdf',
#  '3542359_2013.pdf',
#  '1737242_2013.pdf',
#  '1001174_2013.pdf',
#  '823435_2013.pdf',
#  '1378996_2013_3.pdf',
#  '1886495_2013.pdf',
#  '1555610_2013.pdf',
#  '1189251_2013.pdf',
#  '705190_2013.pdf',
#  '1897783_2013.pdf',
#  '1274778_2014.pdf',
#  '262677_2013.pdf',
#  '3984772_2013.pdf',
#  '1708767_2013.pdf',
#  '1025360_2013.pdf',
#  '367979_2013.pdf',
#  '2188425_2013.pdf',
#  '229430_2013.pdf',
#  '796721_2013.pdf',
#  '710600_2013.pdf',
#  '615516_2013.pdf',
#  '1370823_2013.pdf',
#  '1287501_2013.pdf',
#  '498782_2013.pdf',
#  '1037963_2013_1.pdf',
#  '579971_2013.pdf',
#  '612660_2013.pdf',
#  '670028_2013.pdf',
#  '1174592_2013.pdf',
#  '747690_2014_1.pdf',
#  '295470_2013.pdf',
#  '577360_2013.pdf',
#  '787641_2013.pdf',
#  '875792_2013_1.pdf',
#  '741968_2013.pdf',
#  '1229107_2013.pdf',
#  '876376_2013.pdf',
#  '210092_2013.pdf',
#  '4589708_2013_1.pdf',
#  '674974_2014_1.pdf',
#  '728261_2013.pdf',
#  '834661_2013.pdf',
#  '810717_2013.pdf',
#  '488408_2013.pdf',
#  '1444987_2013.pdf',
#  '763525_2013.pdf',
#  '836029_2013.pdf',
#  '2911406_2013.pdf',
#  '2062932_2013.pdf',
#  '747690_2013_1.pdf',
#  '2014351_2013.pdf',
#  '1059215_2013.pdf',
#  '919752_2013.pdf',
#  '912455_2013.pdf',
#  '616396_2013.pdf',
#  '1287336_2013.pdf',
#  '1541333_2013.pdf',
#  '448833_2013.pdf',
#  '717177_2013.pdf',
#  '1060330_2013.pdf',
#  '813839_2013.pdf',
#  '803838_2013.pdf',
#  '796567_2013.pdf',
#  '264680_2013.pdf',
#  '633263_2014.pdf',
#  '2188426_2013_1.pdf',
#  '2909541_2013.pdf',
#  '650349_2013_1.pdf',
#  '931163_2014.pdf',
#  '838037_2013.pdf',
#  '804574_2013.pdf',
#  '498782_2013_1.pdf',
#  '251038_2013.pdf',
#  '1547726_2013.pdf',
#  '748313_2013.pdf',
#  '1080834_2013.pdf',
#  '495949_2013.pdf',
#  '882802_2013.pdf',
#  '299898_2013.pdf',
#  '1378996_2013_1.pdf',
#  '912240_2013.pdf',
#  '1434490_2013.pdf',
#  '577360_2013_1.pdf',
#  '1001174_2014.pdf',
#  '1704686_2013.pdf',
#  '626442_2013.pdf',
#  '1362904_2013.pdf',
#  '830834_2013.pdf',
#  '513594_2013.pdf',
#  '1084509_2013.pdf',
#  '1066632_2013.pdf',
#  '1213877_2013.pdf',
#  '838772_2013.pdf',
#  '942446_2014.pdf',
#  '990058_2013_1.pdf',
#  '1986363_2013_1.pdf',
#  '1000687_2013.pdf',
#  '926491_2013.pdf',
#  '633263_2013.pdf',
#  '802718_2013.pdf',
#  '1190973_2013.pdf',
#  '409675_2013.pdf',
#  '644422_2013.pdf',
#  '942446_2013.pdf',
#  '513612_2013.pdf',
#  '878021_2013.pdf',
#  '1397342_2013.pdf',
#  '350669_2013.pdf',
#  '747690_2013_2.pdf',
#  '1174334_2013.pdf',
#  '650349_2013_2.pdf',
#  '456160_2013.pdf',
#  '1412612_2013_1.pdf',
#  '838772_2013_1.pdf',
#  '744744_2013.pdf',
#  '382381_2013.pdf',
#  '881086_2013.pdf',
#  '352311_2013.pdf',
#  '434900_2013.pdf',
#  '749218_2013.pdf',
#  '4589708_2013.pdf',
#  '886685_2014.pdf',
#  '644091_2014.pdf',
#  '2281674_2013.pdf',
#  '747690_2013_3.pdf',
#  '439926_2013.pdf',
#  '480417_2013.pdf',
#  '520241_2013.pdf',
#  '757819_2013.pdf',
#  '566622_2013.pdf',
#  '1397342_2013_1.pdf',
#  '480417_2013_1.pdf',
#  '886685_2014_1.pdf',
#  '833523_2013.pdf',
#  '1058377_2013.pdf',
#  '1461189_2013.pdf',
#  '1061496_2013.pdf',
#  '1705844_2013.pdf',
#  '1986363_2013.pdf',
#  '425103_2013.pdf',
#  '1708434_2013.pdf',
#  '425103_2014.pdf',
#  '1465992_2014.pdf',
#  '674974_2013_1.pdf',
#  '788697_2013.pdf',
#  '229430_2013_1.pdf',
#  '1452998_2013.pdf',
#  '738164_2013_1.pdf',
#  '1413211_2013.pdf',
#  '674974_2013.pdf',
#  '95732_2013.pdf',
#  '428118_2013.pdf',
#  '674198_2013.pdf',
#  '2586412_2013.pdf',
#  '747690_2014.pdf',
#  '870250_2013.pdf',
#  '524875_2013.pdf',
#  '990058_2013.pdf',
#  '760447_2013.pdf',
#  '1614778_2013.pdf',
#  '2014351_2013_1.pdf',
#  '2586754_2013.pdf',
#  '540041_2013.pdf',
#  '583032_2013.pdf',
#  '747690_2013.pdf',
#  '1378996_2013.pdf',
#  '1000687_2013_1.pdf',
#  '661271_2014.pdf',
#  '1057219_2014_2.pdf',
#  '674974_2014.pdf',
#  '1037963_2013.pdf',
#  '1357964_2013.pdf']
